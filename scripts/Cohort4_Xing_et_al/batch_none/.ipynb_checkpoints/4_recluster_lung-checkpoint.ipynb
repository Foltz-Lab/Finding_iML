# %%
import scanpy as sc
import anndata
import pandas as pd
from matplotlib import rcParams
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
adata = sc.read_h5ad("/Volumes/jennifer.a.foltz/Active/Veda/pan_cancer/Fan_brain_met/Xing_rds/batch_none/Fan_nk_eMLclassified_adata_batch_none.h5ad")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 10353 × 4000
#     obs: 'Disease', 'Study', 'SampleID', 'CancerType', 'CancerSubtype', 'EGFRtype', 'Treatment', 'Celltype', 'Subtype', 'batch', 'celltype.l2', 'dataset_name', '_scvi_labels', '_scvi_batch', 'CD56brightBBCprob', 'CD56dimBBCprob', 'eML1BBCprob', 'eML2BBCprob', 'predictionsBBC'
#     uns: '_scvi_manager_uuid', '_scvi_uuid'
#     obsm: 'X_totalvi_scarches', 'protein_expression'
#     layers: 'counts'

# %%
adata.obs
# Out:
#                                 Disease Study SampleID CancerType  \
# Xing_BrM02_LC_AATGGAACAACGGCCT      BrM  Xing    BrM02         LC
# Xing_BrM02_LC_AGTGTTGGTGAATGTA      BrM  Xing    BrM02         LC
# Xing_BrM02_LC_CCACAAAAGACCGTTT      BrM  Xing    BrM02         LC
# Xing_BrM02_LC_CGAAGGATCACCACAA      BrM  Xing    BrM02         LC
# Xing_BrM02_LC_CTAGACAAGTAAGCAT      BrM  Xing    BrM02         LC
# ...                                 ...   ...      ...        ...
# Xing_BrM99_HCC_TTTAGTCGTGCCTTCT     BrM  Xing    BrM99        HCC
# Xing_BrM99_HCC_TTTATGCTCCACTGGG     BrM  Xing    BrM99        HCC
# Xing_BrM99_HCC_TTTGATCGTGCGACAA     BrM  Xing    BrM99        HCC
# Xing_BrM99_HCC_TTTGGAGTCAACCTTT     BrM  Xing    BrM99        HCC
# Xing_BrM99_HCC_TTTGTTGTCGATCCAA     BrM  Xing    BrM99        HCC
#
#                                 CancerSubtype EGFRtype Treatment   Celltype  \
# Xing_BrM02_LC_AATGGAACAACGGCCT          Other    Other     Naive  T/NK cell
# Xing_BrM02_LC_AGTGTTGGTGAATGTA          Other    Other     Naive  T/NK cell
# Xing_BrM02_LC_CCACAAAAGACCGTTT          Other    Other     Naive  T/NK cell
# Xing_BrM02_LC_CGAAGGATCACCACAA          Other    Other     Naive  T/NK cell
# Xing_BrM02_LC_CTAGACAAGTAAGCAT          Other    Other     Naive  T/NK cell
# ...                                       ...      ...       ...        ...
# Xing_BrM99_HCC_TTTAGTCGTGCCTTCT         Other    Other     Naive  T/NK cell
# Xing_BrM99_HCC_TTTATGCTCCACTGGG         Other    Other     Naive  T/NK cell
# Xing_BrM99_HCC_TTTGATCGTGCGACAA         Other    Other     Naive  T/NK cell
# Xing_BrM99_HCC_TTTGGAGTCAACCTTT         Other    Other     Naive  T/NK cell
# Xing_BrM99_HCC_TTTGTTGTCGATCCAA         Other    Other     Naive  T/NK cell
#
#                                          Subtype     batch celltype.l2  \
# Xing_BrM02_LC_AATGGAACAACGGCCT   L20 : NK-FCGR3A  SampleID     Unknown
# Xing_BrM02_LC_AGTGTTGGTGAATGTA   L20 : NK-FCGR3A  SampleID     Unknown
# Xing_BrM02_LC_CCACAAAAGACCGTTT   L20 : NK-FCGR3A  SampleID     Unknown
# Xing_BrM02_LC_CGAAGGATCACCACAA      L22 : NK-IFN  SampleID     Unknown
# Xing_BrM02_LC_CTAGACAAGTAAGCAT   L20 : NK-FCGR3A  SampleID     Unknown
# ...                                          ...       ...         ...
# Xing_BrM99_HCC_TTTAGTCGTGCCTTCT  L20 : NK-FCGR3A  SampleID     Unknown
# Xing_BrM99_HCC_TTTATGCTCCACTGGG   L19 : NK-NCAM1  SampleID     Unknown
# Xing_BrM99_HCC_TTTGATCGTGCGACAA   L19 : NK-NCAM1  SampleID     Unknown
# Xing_BrM99_HCC_TTTGGAGTCAACCTTT  L20 : NK-FCGR3A  SampleID     Unknown
# Xing_BrM99_HCC_TTTGTTGTCGATCCAA  L20 : NK-FCGR3A  SampleID     Unknown
#
#                                 dataset_name  _scvi_labels  _scvi_batch  \
# Xing_BrM02_LC_AATGGAACAACGGCCT         Query             0            3
# Xing_BrM02_LC_AGTGTTGGTGAATGTA         Query             0            3
# Xing_BrM02_LC_CCACAAAAGACCGTTT         Query             0            3
# Xing_BrM02_LC_CGAAGGATCACCACAA         Query             0            3
# Xing_BrM02_LC_CTAGACAAGTAAGCAT         Query             0            3
# ...                                      ...           ...          ...
# Xing_BrM99_HCC_TTTAGTCGTGCCTTCT        Query             0            3
# Xing_BrM99_HCC_TTTATGCTCCACTGGG        Query             0            3
# Xing_BrM99_HCC_TTTGATCGTGCGACAA        Query             0            3
# Xing_BrM99_HCC_TTTGGAGTCAACCTTT        Query             0            3
# Xing_BrM99_HCC_TTTGTTGTCGATCCAA        Query             0            3
#
#                                  CD56brightBBCprob  CD56dimBBCprob  \
# Xing_BrM02_LC_AATGGAACAACGGCCT            0.005730        0.565306
# Xing_BrM02_LC_AGTGTTGGTGAATGTA            0.000500        0.963111
# Xing_BrM02_LC_CCACAAAAGACCGTTT            0.000239        0.862482
# Xing_BrM02_LC_CGAAGGATCACCACAA            0.000392        0.840216
# Xing_BrM02_LC_CTAGACAAGTAAGCAT            0.000249        0.934569
# ...                                            ...             ...
# Xing_BrM99_HCC_TTTAGTCGTGCCTTCT           0.000207        0.969836
# Xing_BrM99_HCC_TTTATGCTCCACTGGG           0.070726        0.238062
# Xing_BrM99_HCC_TTTGATCGTGCGACAA           0.000998        0.663616
# Xing_BrM99_HCC_TTTGGAGTCAACCTTT           0.004836        0.918610
# Xing_BrM99_HCC_TTTGTTGTCGATCCAA           0.000876        0.941123
#
#                                  eML1BBCprob  eML2BBCprob predictionsBBC
# Xing_BrM02_LC_AATGGAACAACGGCCT      0.372211     0.056753        CD56dim
# Xing_BrM02_LC_AGTGTTGGTGAATGTA      0.032505     0.003885        CD56dim
# Xing_BrM02_LC_CCACAAAAGACCGTTT      0.113108     0.024171        CD56dim
# Xing_BrM02_LC_CGAAGGATCACCACAA      0.052103     0.107289        CD56dim
# Xing_BrM02_LC_CTAGACAAGTAAGCAT      0.045763     0.019419        CD56dim
# ...                                      ...          ...            ...
# Xing_BrM99_HCC_TTTAGTCGTGCCTTCT     0.004853     0.025104        CD56dim
# Xing_BrM99_HCC_TTTATGCTCCACTGGG     0.549249     0.141963            ML1
# Xing_BrM99_HCC_TTTGATCGTGCGACAA     0.077892     0.257494        CD56dim
# Xing_BrM99_HCC_TTTGGAGTCAACCTTT     0.024485     0.052069        CD56dim
# Xing_BrM99_HCC_TTTGTTGTCGATCCAA     0.005506     0.052495        CD56dim
#
# [10353 rows x 19 columns]

# %%
adata.obs["batch"].unique()
# Out:
# ['SampleID']
# Categories (1, object): ['SampleID']

# %%
#Ml transition and unclassified
#argmax error
# Define the column names for probabilities and their corresponding labels
probability_columns = ['CD56brightBBCprob', 'CD56dimBBCprob', 'eML1BBCprob', 'eML2BBCprob']
labels = ['CD56bright', 'CD56dim', 'ML1', 'ML2']

# Ensure the probability columns are numeric
for col in probability_columns:
    adata.obs[col] = pd.to_numeric(adata.obs[col], errors='coerce')  # Convert to numeric, set errors as NaN

# Function to classify rows based on conditions
def classify_row(row):
    # Check if all probabilities are less than 0.5
    if all(row[col] < 0.5 for col in probability_columns):
        # If combined probability of 'eML1BBCprob' and 'eML2BBCprob' is greater than 0.5, classify as ML_transition
        if row['eML1BBCprob'] + row['eML2BBCprob'] > 0.5:
            return 'ML_transition'
        else:
            return 'unclassified'
    else:
        # Find the column with the maximum probability
        max_index = row[probability_columns].astype(float).idxmax()  # Ensure values are treated as numeric
        return labels[probability_columns.index(max_index)]  # Return the corresponding label

# Apply the classification function to each row in `adata.obs`
adata.obs['classification'] = adata.obs.apply(classify_row, axis=1)

# View the first few rows to verify the classification
print(adata.obs[['CD56brightBBCprob', 'CD56dimBBCprob', 'eML1BBCprob', 'eML2BBCprob', 'classification']].head())
# Out:
#                                 CD56brightBBCprob  CD56dimBBCprob  \
# Xing_BrM02_LC_AATGGAACAACGGCCT           0.005730        0.565306
# Xing_BrM02_LC_AGTGTTGGTGAATGTA           0.000500        0.963111
# Xing_BrM02_LC_CCACAAAAGACCGTTT           0.000239        0.862482
# Xing_BrM02_LC_CGAAGGATCACCACAA           0.000392        0.840216
# Xing_BrM02_LC_CTAGACAAGTAAGCAT           0.000249        0.934569
#
#                                 eML1BBCprob  eML2BBCprob classification
# Xing_BrM02_LC_AATGGAACAACGGCCT     0.372211     0.056753        CD56dim
# Xing_BrM02_LC_AGTGTTGGTGAATGTA     0.032505     0.003885        CD56dim
# Xing_BrM02_LC_CCACAAAAGACCGTTT     0.113108     0.024171        CD56dim
# Xing_BrM02_LC_CGAAGGATCACCACAA     0.052103     0.107289        CD56dim
# Xing_BrM02_LC_CTAGACAAGTAAGCAT     0.045763     0.019419        CD56dim

# %%
adata.obs["classification"].value_counts()
# Out:
# classification
# CD56dim          6124
# ML1              1761
# ML_transition     816
# CD56bright        785
# ML2               508
# unclassified      359
# Name: count, dtype: int64

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 10353 × 4000
#     obs: 'Disease', 'Study', 'SampleID', 'CancerType', 'CancerSubtype', 'EGFRtype', 'Treatment', 'Celltype', 'Subtype', 'batch', 'celltype.l2', 'dataset_name', '_scvi_labels', '_scvi_batch', 'CD56brightBBCprob', 'CD56dimBBCprob', 'eML1BBCprob', 'eML2BBCprob', 'predictionsBBC', 'classification'
#     uns: '_scvi_manager_uuid', '_scvi_uuid'
#     obsm: 'X_totalvi_scarches', 'protein_expression'
#     layers: 'counts'

# %%
adata.obs["CancerType"].value_counts()
# Out:
# CancerType
# LC         5486
# HCC        1301
# BC         1262
# CRC        1243
# Other       338
# ESCC        313
# MEL         286
# Sarcoma     124
# Name: count, dtype: int64

# %%
adata_lung= adata[adata.obs['CancerType'] == 'LC'].copy()

# %%
adata_lung
# Out:
# AnnData object with n_obs × n_vars = 5486 × 4000
#     obs: 'Disease', 'Study', 'SampleID', 'CancerType', 'CancerSubtype', 'EGFRtype', 'Treatment', 'Celltype', 'Subtype', 'batch', 'celltype.l2', 'dataset_name', '_scvi_labels', '_scvi_batch', 'CD56brightBBCprob', 'CD56dimBBCprob', 'eML1BBCprob', 'eML2BBCprob', 'predictionsBBC', 'classification'
#     uns: '_scvi_manager_uuid', '_scvi_uuid'
#     obsm: 'X_totalvi_scarches', 'protein_expression'
#     layers: 'counts'

# %%
sc.pl.highest_expr_genes(adata_lung, n_top= 20)

# %%
sc.pp.filter_genes(adata_lung, min_cells = 10)

# %%
sc.pp.normalize_total(adata_lung, target_sum=1e4)

# %%
sc.pp.log1p(adata_lung)

# %%
adata_lung.obs.SampleID = adata_lung.obs.SampleID.astype('category')

# %%
sc.pp.highly_variable_genes(adata_lung, batch_key = 'SampleID')

# %%
sc.pl.highly_variable_genes(adata_lung)

# %%
adata_lung.raw = adata_lung

# %%
#sc.pp.regress_out(adata, ['S.Score', 'G2M.Score']) 
sc.pp.scale(adata_lung,max_value=10)

# %%
sc.tl.pca(adata_lung)
sc.pl.pca(adata_lung, color = ['SampleID'])

# %%
sc.external.pp.harmony_integrate(adata_lung,key='SampleID')
# Out:
# 2025-07-11 18:00:47,070 - harmonypy - INFO - Computing initial centroids with sklearn.KMeans...
# 2025-07-11 18:00:48,904 - harmonypy - INFO - sklearn.KMeans initialization complete.
# 2025-07-11 18:00:48,929 - harmonypy - INFO - Iteration 1 of 10
# 2025-07-11 18:00:50,418 - harmonypy - INFO - Iteration 2 of 10
# 2025-07-11 18:00:51,567 - harmonypy - INFO - Iteration 3 of 10
# 2025-07-11 18:00:52,787 - harmonypy - INFO - Iteration 4 of 10
# 2025-07-11 18:00:53,509 - harmonypy - INFO - Iteration 5 of 10
# 2025-07-11 18:00:54,190 - harmonypy - INFO - Iteration 6 of 10
# 2025-07-11 18:00:54,885 - harmonypy - INFO - Iteration 7 of 10
# 2025-07-11 18:00:55,482 - harmonypy - INFO - Iteration 8 of 10
# 2025-07-11 18:00:56,001 - harmonypy - INFO - Iteration 9 of 10
# 2025-07-11 18:00:56,529 - harmonypy - INFO - Iteration 10 of 10
# 2025-07-11 18:00:57,026 - harmonypy - INFO - Stopped before convergence

# %%
adata_lung.obsm['X_pca'] = adata_lung.obsm['X_pca_harmony']
sc.pl.pca(adata_lung, color = ['SampleID'])

# %%
#sc.pl.pca(adata, color = ['Phase'])
sc.pl.pca_variance_ratio(adata_lung, log=True)  # select significant PCs for input into neighbors

# %%
sc.pl.pca_variance_ratio(adata_lung, log=False, n_pcs=50)

# %%
sc.pp.neighbors(adata_lung, n_pcs=19)

# %%
sc.tl.paga(adata_lung,groups='classification')

# %%
sc.pl.paga(adata_lung)
sc.tl.umap(adata_lung, init_pos='paga')

# %%
sc.pl.umap(adata_lung, color = "SampleID")
sc.tl.embedding_density(adata_lung, basis = 'umap',groupby='classification')

# %%
sc.pl.embedding_density(adata_lung,basis='umap', key = 'umap_density_classification', ncols = 3, fg_dotsize = 100)
sc.tl.leiden(adata_lung, resolution = 0.8)

# %%
print(pd.crosstab(adata_lung.obs['leiden'],adata.obs['classification'], normalize = 'columns'))
sc.pl.umap(adata_lung, color = 'leiden')
# Out:
# classification  CD56bright   CD56dim       ML1       ML2  ML_transition  \
# leiden
# 0                 0.381517  0.115182  0.367248  0.331210       0.353183
# 1                 0.241706  0.048185  0.483527  0.264331       0.305955
# 2                 0.021327  0.251155  0.019380  0.079618       0.061602
# 3                 0.009479  0.218482  0.014535  0.012739       0.026694
# 4                 0.004739  0.195050  0.010659  0.095541       0.094456
# 5                 0.265403  0.026073  0.039729  0.003185       0.034908
# 6                 0.045024  0.038944  0.025194  0.156051       0.080082
# 7                 0.021327  0.046865  0.028101  0.044586       0.018480
# 8                 0.004739  0.031353  0.005814  0.009554       0.014374
# 9                 0.004739  0.028713  0.005814  0.003185       0.010267
#
# classification  unclassified
# leiden
# 0                   0.482587
# 1                   0.194030
# 2                   0.024876
# 3                   0.014925
# 4                   0.034826
# 5                   0.154229
# 6                   0.074627
# 7                   0.014925
# 8                   0.000000
# 9                   0.004975

# %%
sc.pl.umap(adata_lung, color = 'classification', size=20)
